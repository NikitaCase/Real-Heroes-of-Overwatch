# %%
import pandas as pd
import csv

# %%
d1 = 'phs_2019_stage_1.csv'
d2 = 'phs_2019_stage_2.csv'
d3 = 'phs_2019_stage_3.csv'
d4 = 'phs_2019_stage_4.csv'

# %%
df1 = pd.read_csv(d1)
df2 = pd.read_csv(d2)
df3 = pd.read_csv(d3)
df4 = pd.read_csv(d4)

# %%
df22 = df1.append(df2)
df44 = df3.append(df4)
overwatch_df = df22.append(df44)
overwatch_df.head()
# Out:
#     pelstart_time  match_id                     stage map_type map_name  \
# 0  2/15/2019 0:11     21211  Overwatch League Stage 1  CONTROL    Ilios
# 1  2/15/2019 0:11     21211  Overwatch League Stage 1  CONTROL    Ilios
# 2  2/15/2019 0:11     21211  Overwatch League Stage 1  CONTROL    Ilios
# 3  2/15/2019 0:11     21211  Overwatch League Stage 1  CONTROL    Ilios
# 4  2/15/2019 0:11     21211  Overwatch League Stage 1  CONTROL    Ilios
#
#    player             team             stat_name        hero   stat_amount  \
# 0  Bdosin  London Spitfire       All Damage Done  All Heroes  14845.193400
# 1  Bdosin  London Spitfire               Assists  All Heroes     13.000000
# 2  Bdosin  London Spitfire    Average Time Alive  All Heroes     87.623574
# 3  Bdosin  London Spitfire   Barrier Damage Done  All Heroes   5674.344475
# 4  Bdosin  London Spitfire  Damage - Quick Melee  All Heroes     78.000000
#
#   start_time
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# ...

# %%
Bischu = overwatch_df.loc[overwatch_df['player']=='Bischu', :]
Bischu
# Out:
#       pelstart_time  match_id                     stage map_type map_name  \
# 54029           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# 54030           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# 54031           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# 54032           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# 54033           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# ...             ...       ...                       ...      ...      ...
# 54130           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# 54131           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# 54132           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# 54133           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
# 54134           NaN     21397  Overwatch League Stage 4  PAYLOAD   Havana
#
#        player              team                      stat_name        hero  \
# ...
