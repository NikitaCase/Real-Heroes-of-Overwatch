# %%
# import dependecies 
import pandas as pd
import csv
import os

# %%
# creates path for csv datafile
file1= "phs_2019_stage_1.csv"
file2= "phs_2019_stage_2.csv"
file3= "phs_2019_stage_3.csv"
file4= "phs_2019_stage_4.csv"  
file5= "phs_2019_playoffs.csv"

# %%
# reads the csv and transforms it into a dataframe
overwatch_df_1 = pd.read_csv(file1)
overwatch_df_2 = pd.read_csv(file2)
overwatch_df_3 = pd.read_csv(file3)
overwatch_df_4 = pd.read_csv(file4)
overwatch_df_5 = pd.read_csv(file5)

# %%
complete_overwatch_df = overwatch_df_1.append([overwatch_df_2, overwatch_df_3, overwatch_df_4, overwatch_df_5])

# %%
complete_overwatch_df
# Out:
#          pelstart_time  match_id                              stage map_type  \
# 0       2/15/2019 0:11     21211           Overwatch League Stage 1  CONTROL
# 1       2/15/2019 0:11     21211           Overwatch League Stage 1  CONTROL
# 2       2/15/2019 0:11     21211           Overwatch League Stage 1  CONTROL
# 3       2/15/2019 0:11     21211           Overwatch League Stage 1  CONTROL
# 4       2/15/2019 0:11     21211           Overwatch League Stage 1  CONTROL
# ...                ...       ...                                ...      ...
# 103967             NaN     30157  Overwatch League 2019 Post-Season  PAYLOAD
# 103968             NaN     30157  Overwatch League 2019 Post-Season  PAYLOAD
# 103969             NaN     30157  Overwatch League 2019 Post-Season  PAYLOAD
# 103970             NaN     30157  Overwatch League 2019 Post-Season  PAYLOAD
# 103971             NaN     30157  Overwatch League 2019 Post-Season  PAYLOAD
#
#                      map_name    player              team  \
# 0                       Ilios    Bdosin   London Spitfire
# 1                       Ilios    Bdosin   London Spitfire
# 2                       Ilios    Bdosin   London Spitfire
# 3                       Ilios    Bdosin   London Spitfire
# 4                       Ilios    Bdosin   London Spitfire
# ...                       ...       ...               ...
# 103967  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103968  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103969  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103970  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103971  Watchpoint: Gibraltar  Twilight  Vancouver Titans
#
#                    stat_name        hero   stat_amount       start_time
# 0            All Damage Done  All Heroes  14845.193400              NaN
# 1                    Assists  All Heroes     13.000000              NaN
# 2         Average Time Alive  All Heroes     87.623574              NaN
# 3        Barrier Damage Done  All Heroes   5674.344475              NaN
# 4       Damage - Quick Melee  All Heroes     78.000000              NaN
# ...                      ...         ...           ...              ...
# 103967        Ultimates Used         Ana      6.000000  9/29/2019 20:47
# 103968     Unscoped Accuracy         Ana      0.528777  9/29/2019 20:47
# 103969         Unscoped Hits         Ana    147.000000  9/29/2019 20:47
# 103970        Unscoped Shots         Ana    278.000000  9/29/2019 20:47
# 103971       Weapon Accuracy         Ana      0.273504  9/29/2019 20:47
#
# [1557832 rows x 11 columns]

# %%
# drops the columns below
dropped_complete_overwatch_df = complete_overwatch_df.drop(columns=["pelstart_time", "stage",  "match_id", "start_time"])

# %%
# Creates a list of the rows we would liek to keep
stats = ["All Damage Done", "Assists", "Average Time Alive", "Critical Hit Accuracy", "Damage - Weapon Primary",  "Damage - Weapon Secondary", "Damage Blocked", "Damage Done", "Damage Taken", "Deaths", "Eliminations", "Healing Done", "Multikills", "Primary Fire Accuracy", "Primary Fire Hits", "Secondary Fire Accuracy", "Secondary Fire Hits", "Time Alive", "Weapon Accuracy"]

# %%
# Drops the row names that aren't included in the the list
stats_df = dropped_complete_overwatch_df[dropped_complete_overwatch_df['stat_name'].isin(stats)]

# %%
# Displays new dataframe
stats_df
# Out:
#        map_type               map_name    player              team  \
# 0       CONTROL                  Ilios    Bdosin   London Spitfire
# 1       CONTROL                  Ilios    Bdosin   London Spitfire
# 2       CONTROL                  Ilios    Bdosin   London Spitfire
# 5       CONTROL                  Ilios    Bdosin   London Spitfire
# 6       CONTROL                  Ilios    Bdosin   London Spitfire
# ...         ...                    ...       ...               ...
# 103931  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103939  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103942  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103961  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103971  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
#
#                  stat_name        hero   stat_amount
# 0          All Damage Done  All Heroes  14845.193400
# 1                  Assists  All Heroes     13.000000
# 2       Average Time Alive  All Heroes     87.623574
# 5              Damage Done  All Heroes   9039.330256
# 6             Damage Taken  All Heroes   4192.611340
# ...                    ...         ...           ...
# 103931        Eliminations         Ana     19.000000
# 103939        Healing Done         Ana  10009.825090
# 103942          Multikills         Ana      2.000000
# 103961          Time Alive         Ana    765.860023
# 103971     Weapon Accuracy         Ana      0.273504
#
# [465346 rows x 7 columns]

# %%
# Rounds the stat_amount to four decimal places
rounded_stats_df = stats_df.round({"stat_amount" : 4})

# %%
# displays new dataframe 
rounded_stats_df
# Out:
#        map_type               map_name    player              team  \
# 0       CONTROL                  Ilios    Bdosin   London Spitfire
# 1       CONTROL                  Ilios    Bdosin   London Spitfire
# 2       CONTROL                  Ilios    Bdosin   London Spitfire
# 5       CONTROL                  Ilios    Bdosin   London Spitfire
# 6       CONTROL                  Ilios    Bdosin   London Spitfire
# ...         ...                    ...       ...               ...
# 103931  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103939  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103942  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103961  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
# 103971  PAYLOAD  Watchpoint: Gibraltar  Twilight  Vancouver Titans
#
#                  stat_name        hero  stat_amount
# 0          All Damage Done  All Heroes   14845.1934
# 1                  Assists  All Heroes      13.0000
# 2       Average Time Alive  All Heroes      87.6236
# 5              Damage Done  All Heroes    9039.3303
# 6             Damage Taken  All Heroes    4192.6113
# ...                    ...         ...          ...
# 103931        Eliminations         Ana      19.0000
# 103939        Healing Done         Ana   10009.8251
# 103942          Multikills         Ana       2.0000
# 103961          Time Alive         Ana     765.8600
# 103971     Weapon Accuracy         Ana       0.2735
#
# [465346 rows x 7 columns]
